# %%
# !pip install catboost==1.2

# %%
import pandas as pd
import re
from datetime import datetime as dt
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split
from catboost.utils import eval_metric
import numpy as np

# %% [markdown]
# ### Read df

# %%
df = pd.read_csv('data/embeddings.csv')

# %%
#df = df['text','linkedid','cat','embeddings']
df = df[['text', 'cat', 'embedding']]
df.head(3)
# Out:
#                                   text  cat  \
# 0  центра пётр наталья чем могу помочь  1.0
# 1                          до свидания  1.0
# 2       ожидайте звонок в течение часа  1.0
#
#                                            embedding
# 0  [ 1.33301303e-01  1.38765112e-01 -5.30672930e-...
# 1  [-6.47988096e-02  5.10487437e-01 -6.43889159e-...
# 2  [-1.26493618e-01  3.18099082e-01 -8.92290846e-...

# %% [markdown]
# ### Create embeddings columns

# %%
# Defining a function to extract the float values from the string representation
def extract_values(embedding_str):
    # Using regular expression to find all floating-point numbers in the string
    values = re.findall(r'[-+]?\d*\.\d+e[+-]\d+|[-+]?\d+\.\d+|\d+', embedding_str)
    return [float(value) for value in values]

# Applying the function to the "embedding" column to create a DataFrame with new columns
embedding_values_df = df['embedding'].apply(extract_values).apply(pd.Series)

# Renaming the columns to "emb_0," "emb_1," etc.
embedding_values_df.columns = [f'emb_{i}' for i in range(embedding_values_df.shape[1])]

# Concatenating the new columns with the original DataFrame
final_df = pd.concat([df.drop(columns=['embedding']), embedding_values_df], axis=1)

# Displaying the first few rows of the final DataFrame
final_df.head(3)
# Out:
#                                   text  cat     emb_0     emb_1     emb_2  \
# 0  центра пётр наталья чем могу помочь  1.0  0.133301  0.138765 -0.053067
# 1                          до свидания  1.0 -0.064799  0.510487 -0.064389
# 2       ожидайте звонок в течение часа  1.0 -0.126494  0.318099 -0.089229
#
#       emb_3     emb_4     emb_5     emb_6     emb_7  ...   emb_374   emb_375  \
# 0  0.216577 -0.115041  0.215542  0.418259  0.268942  ... -0.104017  0.080503
# 1 -0.150583 -0.298217 -0.038162  0.586201  0.035760  ... -0.107713  0.585010
# 2  0.029890 -0.087400  0.033627  0.595477  0.404032  ... -0.004513  0.180154
#
#     emb_376   emb_377   emb_378   emb_379   emb_380   emb_381   emb_382  \
# 0  0.317190  0.141871 -0.503967 -0.094222 -0.272026  0.085119  0.067764
# 1  0.127220 -0.140590 -0.249223 -0.065519  0.000537  0.334044 -0.096987
# 2  0.365843 -0.024833 -0.129964 -0.091756 -0.099174  0.082055 -0.041417
#
#     emb_383
# 0 -0.176453
# 1 -0.465870
# 2 -0.255874
#
# [3 rows x 386 columns]

# %% [markdown]
# ### CatBoost regression

# %%
final_df.to_csv('catboost_in.csv')

# %%
# final_df = pd.read_csv('catboost_in.csv')

# %%
# define dataset
X = final_df.drop(final_df[['text', 'cat']], axis=1)
y = final_df['cat']

# %%
# dataset preparation
X_train, X_validation, y_train, y_validation = train_test_split(X, y, train_size=0.75, random_state=42)
eval_dataset = Pool(data=X_validation,
        label=y_validation)

# %%
len(y_train), sum(y_train)
# Out:
# (293252, 274880.0)

# %%
len(y_validation), sum(y_validation)
# Out:
# (97751, 91603.0)

# %%
model = CatBoostRegressor(
            boost_from_average=True,
            one_hot_max_size = 128,
            depth = 12,
            langevin = True,
            verbose=False,
            task_type="GPU"
            )

# %%
# train
print(dt.now())
model.fit(X_train, y_train, use_best_model=True, eval_set=eval_dataset)
print(dt.now())
# Out:
# 2023-08-26 03:14:37.475400
# 2023-08-26 03:15:39.884868

# %%
# evaluate model score
pred = model.predict(X_validation)
params = model.get_params()
response = ''
response += str(params)+'\n'
response += '\n'+params['loss_function']+' loss: '+ str(eval_metric(y_validation.to_numpy(), pred, params['loss_function']))
response += '\nFitted: '+str(model.is_fitted())
response += '\nModel score:\n'+str(model.score(X,y))
response += '\nFeature importance:'
try:
    importance = model.get_feature_importance()
    for i in range(len(model.feature_names_)):
        response += '\n'+str(np.round(importance[i],2)) + ' ' + model.feature_names_[i]
except Exception as e:
    response += '\n'+str(e)       

response = str(eval_metric(y_validation.to_numpy(), pred, params['loss_function'])[0]) + '\n' + response
print(response)
# Out:
# 0.23723375851366227
# {'depth': 12, 'loss_function': 'RMSE', 'verbose': False, 'one_hot_max_size': 128, 'task_type': 'GPU', 'langevin': True, 'boost_from_average': True}
#
# RMSE loss: [0.23723375851366227]
# Fitted: True
# Model score:
# 0.2083137711417694
# Feature importance:
# 0.25 emb_0
# 2.04 emb_1
# 0.09 emb_2
# 0.1 emb_3
# 0.65 emb_4
# 0.26 emb_5
# 0.17 emb_6
# 0.09 emb_7
# 0.3 emb_8
# 0.0 emb_9
# 0.44 emb_10
# 0.19 emb_11
# 0.75 emb_12
# 0.47 emb_13
# 1.63 emb_14
# 0.29 emb_15
# 0.13 emb_16
# 0.16 emb_17
# 0.68 emb_18
# 0.8 emb_19
# 0.07 emb_20
# 0.21 emb_21
# 0.4 emb_22
# 0.08 emb_23
# 0.05 emb_24
# 0.83 emb_25
# 0.58 emb_26
# 0.22 emb_27
# 0.14 emb_28
# 0.22 emb_29
# 0.29 emb_30
# 0.21 emb_31
# 0.49 emb_32
# 0.27 emb_33
# 0.36 emb_34
# 0.17 emb_35
# 0.05 emb_36
# 0.33 emb_37
# 0.27 emb_38
# 0.31 emb_39
# 0.06 emb_40
# 0.51 emb_41
# 0.04 emb_42
# 0.4 emb_43
# 0.26 emb_44
# 0.55 emb_45
# 0.44 emb_46
# 0.25 emb_47
# 0.03 emb_48
# 0.26 emb_49
# 0.07 emb_50
# 0.03 emb_51
# 0.3 emb_52
# 0.21 emb_53
# 0.2 emb_54
# 0.33 emb_55
# 0.14 emb_56
# 0.06 emb_57
# 0.06 emb_58
# 0.09 emb_59
# 0.01 emb_60
# 0.17 emb_61
# 0.08 emb_62
# 0.64 emb_63
# 0.05 emb_64
# 0.26 emb_65
# 0.14 emb_66
# 0.23 emb_67
# 0.17 emb_68
# 0.23 emb_69
# 0.08 emb_70
# 0.3 emb_71
# 0.28 emb_72
# 0.17 emb_73
# 0.13 emb_74
# 0.13 emb_75
# 0.05 emb_76
# 0.13 emb_77
# 0.2 emb_78
# 0.71 emb_79
# 0.14 emb_80
# 0.27 emb_81
# 0.22 emb_82
# 0.14 emb_83
# 0.29 emb_84
# 0.16 emb_85
# 0.32 emb_86
# 0.05 emb_87
# 0.21 emb_88
# 0.45 emb_89
# 0.24 emb_90
# 0.06 emb_91
# 0.27 emb_92
# 0.19 emb_93
# 0.35 emb_94
# 0.26 emb_95
# 0.0 emb_96
# 0.76 emb_97
# 0.25 emb_98
# 0.33 emb_99
# 0.18 emb_100
# 0.06 emb_101
# 0.1 emb_102
# 0.35 emb_103
# 0.3 emb_104
# 2.23 emb_105
# 0.17 emb_106
# 0.07 emb_107
# 0.09 emb_108
# 0.97 emb_109
# 0.16 emb_110
# 0.11 emb_111
# 0.12 emb_112
# 0.36 emb_113
# 0.31 emb_114
# 0.17 emb_115
# 0.04 emb_116
# 0.09 emb_117
# 0.09 emb_118
# 0.19 emb_119
# 0.02 emb_120
# 0.18 emb_121
# 0.42 emb_122
# 0.33 emb_123
# 0.1 emb_124
# 0.17 emb_125
# 0.92 emb_126
# 0.32 emb_127
# 0.35 emb_128
# 0.42 emb_129
# 0.13 emb_130
# 0.06 emb_131
# 0.15 emb_132
# 1.0 emb_133
# 1.47 emb_134
# 0.18 emb_135
# 0.21 emb_136
# 0.12 emb_137
# 0.36 emb_138
# 0.17 emb_139
# 0.1 emb_140
# 0.1 emb_141
# 0.33 emb_142
# 0.37 emb_143
# 0.1 emb_144
# 0.3 emb_145
# 0.36 emb_146
# 0.08 emb_147
# 0.2 emb_148
# 0.14 emb_149
# 0.33 emb_150
# 0.47 emb_151
# 0.07 emb_152
# 0.34 emb_153
# 0.06 emb_154
# 0.19 emb_155
# 1.27 emb_156
# 0.31 emb_157
# 0.01 emb_158
# 0.12 emb_159
# 0.19 emb_160
# 0.26 emb_161
# 0.28 emb_162
# 0.07 emb_163
# 0.08 emb_164
# 0.02 emb_165
# 0.13 emb_166
# 0.29 emb_167
# 0.16 emb_168
# 0.04 emb_169
# 0.17 emb_170
# 0.13 emb_171
# 0.03 emb_172
# 0.24 emb_173
# 0.65 emb_174
# 0.18 emb_175
# 0.06 emb_176
# 0.43 emb_177
# 0.26 emb_178
# 0.12 emb_179
# 0.29 emb_180
# 0.2 emb_181
# 0.44 emb_182
# 0.15 emb_183
# 0.17 emb_184
# 0.37 emb_185
# 0.25 emb_186
# 0.22 emb_187
# 0.39 emb_188
# 0.07 emb_189
# 0.29 emb_190
# 0.49 emb_191
# 0.65 emb_192
# 0.29 emb_193
# 0.41 emb_194
# 0.06 emb_195
# 0.58 emb_196
# 0.11 emb_197
# 0.16 emb_198
# 0.03 emb_199
# 0.12 emb_200
# 0.3 emb_201
# 0.13 emb_202
# 0.15 emb_203
# 0.31 emb_204
# 0.23 emb_205
# 0.28 emb_206
# 0.9 emb_207
# 0.33 emb_208
# 0.03 emb_209
# 0.12 emb_210
# 0.29 emb_211
# 0.16 emb_212
# 0.14 emb_213
# 0.09 emb_214
# 0.05 emb_215
# 0.05 emb_216
# 0.3 emb_217
# 0.4 emb_218
# 0.22 emb_219
# 0.07 emb_220
# 0.42 emb_221
# 0.1 emb_222
# 0.27 emb_223
# 0.11 emb_224
# 0.34 emb_225
# 0.1 emb_226
# 0.45 emb_227
# 0.17 emb_228
# 0.16 emb_229
# 0.84 emb_230
# 0.34 emb_231
# 0.3 emb_232
# 0.36 emb_233
# 0.14 emb_234
# 0.2 emb_235
# 0.17 emb_236
# 0.14 emb_237
# 0.2 emb_238
# 0.16 emb_239
# 0.19 emb_240
# 0.23 emb_241
# 0.26 emb_242
# 0.24 emb_243
# 0.19 emb_244
# 0.15 emb_245
# 0.07 emb_246
# 0.85 emb_247
# 0.24 emb_248
# 0.23 emb_249
# 0.23 emb_250
# 0.22 emb_251
# 0.1 emb_252
# 0.1 emb_253
# 0.16 emb_254
# 0.38 emb_255
# 0.17 emb_256
# 0.15 emb_257
# 0.16 emb_258
# 0.3 emb_259
# 0.06 emb_260
# 0.33 emb_261
# 0.57 emb_262
# 0.18 emb_263
# 0.0 emb_264
# 0.11 emb_265
# 0.36 emb_266
# 0.29 emb_267
# 0.26 emb_268
# 0.11 emb_269
# 0.13 emb_270
# 0.97 emb_271
# 0.12 emb_272
# 0.62 emb_273
# 0.25 emb_274
# 0.17 emb_275
# 0.22 emb_276
# 0.47 emb_277
# 0.34 emb_278
# 0.59 emb_279
# 0.82 emb_280
# 0.43 emb_281
# 0.02 emb_282
# 0.55 emb_283
# 0.19 emb_284
# 0.24 emb_285
# 0.33 emb_286
# 0.02 emb_287
# 0.19 emb_288
# 0.07 emb_289
# 0.35 emb_290
# 0.05 emb_291
# 0.42 emb_292
# 0.18 emb_293
# 0.22 emb_294
# 0.08 emb_295
# 0.5 emb_296
# 0.1 emb_297
# 0.35 emb_298
# 0.12 emb_299
# 0.0 emb_300
# 0.11 emb_301
# 0.04 emb_302
# 0.27 emb_303
# 0.12 emb_304
# 0.08 emb_305
# 0.23 emb_306
# 0.01 emb_307
# 0.19 emb_308
# 0.09 emb_309
# 0.0 emb_310
# 0.02 emb_311
# 0.44 emb_312
# 0.07 emb_313
# 0.07 emb_314
# 0.25 emb_315
# 0.1 emb_316
# 0.18 emb_317
# 0.34 emb_318
# 0.06 emb_319
# 0.35 emb_320
# 0.3 emb_321
# 0.27 emb_322
# 0.19 emb_323
# 0.23 emb_324
# 0.33 emb_325
# 0.13 emb_326
# 0.4 emb_327
# 0.04 emb_328
# 0.31 emb_329
# 0.19 emb_330
# 0.13 emb_331
# 0.11 emb_332
# 0.33 emb_333
# 0.41 emb_334
# 0.62 emb_335
# 0.22 emb_336
# 0.17 emb_337
# 0.07 emb_338
# 0.02 emb_339
# 0.06 emb_340
# 0.0 emb_341
# 0.42 emb_342
# 0.16 emb_343
# 0.25 emb_344
# 0.37 emb_345
# 0.3 emb_346
# 0.23 emb_347
# 0.85 emb_348
# 0.17 emb_349
# 0.47 emb_350
# 0.27 emb_351
# 0.26 emb_352
# 0.22 emb_353
# 0.24 emb_354
# 0.25 emb_355
# 0.29 emb_356
# 0.31 emb_357
# 0.15 emb_358
# 0.09 emb_359
# 0.13 emb_360
# 0.15 emb_361
# 0.14 emb_362
# 0.04 emb_363
# 0.35 emb_364
# 0.24 emb_365
# 0.18 emb_366
# 0.13 emb_367
# 0.09 emb_368
# 0.4 emb_369
# 0.22 emb_370
# 0.08 emb_371
# 0.24 emb_372
# 0.29 emb_373
# 0.31 emb_374
# 0.18 emb_375
# 0.14 emb_376
# 0.32 emb_377
# 0.28 emb_378
# 0.19 emb_379
# 0.46 emb_380
# 0.27 emb_381
# 0.33 emb_382
# 0.08 emb_383

# %%
model_name = 'catboost.model'
# save model
model.save_model('data/'+model_name)

# %%
# Sort the feature importance
sorted_importance = sorted(zip(model.feature_names_, importance), key=lambda x: x[1], reverse=True)

# Append sorted feature importance to response
response = '\nSorted Feature importance:'
for i, (feature, imp) in enumerate(sorted_importance):
    response += f'\n{np.round(imp, 2)} {feature}'

print(response)
# Out:
# Sorted Feature importance:
# 2.23 emb_105
# 2.04 emb_1
# 1.63 emb_14
# 1.47 emb_134
# 1.27 emb_156
# 1.0 emb_133
# 0.97 emb_271
# 0.97 emb_109
# 0.92 emb_126
# 0.9 emb_207
# 0.85 emb_348
# 0.85 emb_247
# 0.84 emb_230
# 0.83 emb_25
# 0.82 emb_280
# 0.8 emb_19
# 0.76 emb_97
# 0.75 emb_12
# 0.71 emb_79
# 0.68 emb_18
# 0.65 emb_174
# 0.65 emb_192
# 0.65 emb_4
# 0.64 emb_63
# 0.62 emb_335
# 0.62 emb_273
# 0.59 emb_279
# 0.58 emb_26
# 0.58 emb_196
# 0.57 emb_262
# 0.55 emb_45
# 0.55 emb_283
# 0.51 emb_41
# 0.5 emb_296
# 0.49 emb_191
# 0.49 emb_32
# 0.47 emb_151
# 0.47 emb_277
# 0.47 emb_350
# 0.47 emb_13
# 0.46 emb_380
# 0.45 emb_227
# 0.45 emb_89
# 0.44 emb_182
# 0.44 emb_10
# 0.44 emb_312
# 0.44 emb_46
# 0.43 emb_177
# 0.43 emb_281
# 0.42 emb_292
# 0.42 emb_129
# 0.42 emb_221
# 0.42 emb_342
# 0.42 emb_122
# 0.41 emb_334
# 0.41 emb_194
# 0.4 emb_22
# 0.4 emb_218
# 0.4 emb_43
# 0.4 emb_369
# 0.4 emb_327
# 0.39 emb_188
# 0.38 emb_255
# 0.37 emb_143
# 0.37 emb_185
# 0.37 emb_345
# 0.36 emb_113
# 0.36 emb_233
# 0.36 emb_146
# 0.36 emb_266
# 0.36 emb_34
# 0.36 emb_138
# 0.35 emb_103
# 0.35 emb_364
# 0.35 emb_320
# 0.35 emb_94
# 0.35 emb_298
# 0.35 emb_128
# 0.35 emb_290
# 0.34 emb_318
# 0.34 emb_231
# 0.34 emb_225
# 0.34 emb_153
# 0.34 emb_278
# 0.33 emb_37
# 0.33 emb_333
# 0.33 emb_123
# 0.33 emb_325
# 0.33 emb_99
# 0.33 emb_261
# 0.33 emb_286
# 0.33 emb_55
# 0.33 emb_142
# 0.33 emb_208
# 0.33 emb_150
# 0.33 emb_382
# 0.32 emb_127
# 0.32 emb_377
# 0.32 emb_86
# 0.31 emb_114
# 0.31 emb_374
# 0.31 emb_204
# 0.31 emb_39
# 0.31 emb_357
# 0.31 emb_329
# 0.31 emb_157
# 0.3 emb_52
# 0.3 emb_201
# 0.3 emb_346
# 0.3 emb_259
# 0.3 emb_321
# 0.3 emb_232
# 0.3 emb_145
# 0.3 emb_8
# 0.3 emb_217
# 0.3 emb_104
# 0.3 emb_71
# 0.29 emb_356
# 0.29 emb_167
# 0.29 emb_84
# 0.29 emb_190
# 0.29 emb_267
# 0.29 emb_15
# 0.29 emb_30
# 0.29 emb_193
# 0.29 emb_211
# 0.29 emb_373
# 0.29 emb_180
# 0.28 emb_378
# 0.28 emb_72
# 0.28 emb_206
# 0.28 emb_162
# 0.27 emb_92
# 0.27 emb_381
# 0.27 emb_223
# 0.27 emb_303
# 0.27 emb_33
# 0.27 emb_322
# 0.27 emb_38
# 0.27 emb_351
# 0.27 emb_81
# 0.26 emb_242
# 0.26 emb_352
# 0.26 emb_268
# 0.26 emb_95
# 0.26 emb_178
# 0.26 emb_49
# 0.26 emb_161
# 0.26 emb_65
# 0.26 emb_5
# 0.26 emb_44
# 0.25 emb_47
# 0.25 emb_0
# 0.25 emb_355
# 0.25 emb_344
# 0.25 emb_186
# 0.25 emb_98
# 0.25 emb_315
# 0.25 emb_274
# 0.24 emb_243
# 0.24 emb_285
# 0.24 emb_173
# 0.24 emb_372
# 0.24 emb_248
# 0.24 emb_90
# 0.24 emb_354
# 0.24 emb_365
# 0.23 emb_249
# 0.23 emb_347
# 0.23 emb_69
# 0.23 emb_250
# 0.23 emb_67
# 0.23 emb_306
# 0.23 emb_241
# 0.23 emb_324
# 0.23 emb_205
# 0.22 emb_27
# 0.22 emb_353
# 0.22 emb_82
# 0.22 emb_276
# 0.22 emb_294
# 0.22 emb_187
# 0.22 emb_29
# 0.22 emb_251
# 0.22 emb_336
# 0.22 emb_370
# 0.22 emb_219
# 0.21 emb_31
# 0.21 emb_88
# 0.21 emb_136
# 0.21 emb_21
# 0.21 emb_53
# 0.2 emb_54
# 0.2 emb_78
# 0.2 emb_181
# 0.2 emb_235
# 0.2 emb_148
# 0.2 emb_238
# 0.19 emb_155
# 0.19 emb_93
# 0.19 emb_160
# 0.19 emb_119
# 0.19 emb_240
# 0.19 emb_244
# 0.19 emb_379
# 0.19 emb_11
# 0.19 emb_288
# 0.19 emb_330
# 0.19 emb_284
# 0.19 emb_308
# 0.19 emb_323
# 0.18 emb_293
# 0.18 emb_263
# 0.18 emb_175
# 0.18 emb_366
# 0.18 emb_100
# 0.18 emb_121
# 0.18 emb_317
# 0.18 emb_135
# 0.18 emb_375
# 0.17 emb_35
# 0.17 emb_125
# 0.17 emb_115
# 0.17 emb_275
# 0.17 emb_228
# 0.17 emb_68
# 0.17 emb_184
# 0.17 emb_61
# 0.17 emb_139
# 0.17 emb_106
# 0.17 emb_170
# 0.17 emb_73
# 0.17 emb_349
# 0.17 emb_6
# 0.17 emb_236
# 0.17 emb_256
# 0.17 emb_337
# 0.16 emb_212
# 0.16 emb_343
# 0.16 emb_258
# 0.16 emb_17
# 0.16 emb_239
# 0.16 emb_254
# 0.16 emb_85
# 0.16 emb_168
# 0.16 emb_198
# 0.16 emb_229
# 0.16 emb_110
# 0.15 emb_203
# 0.15 emb_257
# 0.15 emb_358
# 0.15 emb_245
# 0.15 emb_361
# 0.15 emb_183
# 0.15 emb_132
# 0.14 emb_66
# 0.14 emb_362
# 0.14 emb_56
# 0.14 emb_83
# 0.14 emb_149
# 0.14 emb_234
# 0.14 emb_213
# 0.14 emb_28
# 0.14 emb_237
# 0.14 emb_376
# 0.14 emb_80
# 0.13 emb_326
# 0.13 emb_166
# 0.13 emb_130
# 0.13 emb_270
# 0.13 emb_367
# 0.13 emb_331
# 0.13 emb_75
# 0.13 emb_77
# 0.13 emb_74
# 0.13 emb_16
# 0.13 emb_360
# 0.13 emb_171
# 0.13 emb_202
# 0.12 emb_304
# 0.12 emb_299
# 0.12 emb_137
# 0.12 emb_200
# 0.12 emb_179
# 0.12 emb_159
# 0.12 emb_112
# 0.12 emb_210
# 0.12 emb_272
# 0.11 emb_269
# 0.11 emb_301
# 0.11 emb_332
# 0.11 emb_265
# 0.11 emb_111
# 0.11 emb_224
# 0.11 emb_197
# 0.1 emb_140
# 0.1 emb_226
# 0.1 emb_222
# 0.1 emb_253
# 0.1 emb_252
# 0.1 emb_144
# 0.1 emb_102
# 0.1 emb_141
# 0.1 emb_316
# 0.1 emb_297
# 0.1 emb_3
# 0.1 emb_124
# 0.09 emb_368
# 0.09 emb_7
# 0.09 emb_118
# 0.09 emb_59
# 0.09 emb_214
# 0.09 emb_117
# 0.09 emb_309
# 0.09 emb_2
# 0.09 emb_108
# 0.09 emb_359
# 0.08 emb_23
# 0.08 emb_147
# 0.08 emb_371
# 0.08 emb_305
# 0.08 emb_164
# 0.08 emb_70
# 0.08 emb_383
# 0.08 emb_295
# 0.08 emb_62
# 0.07 emb_107
# 0.07 emb_289
# 0.07 emb_189
# 0.07 emb_246
# 0.07 emb_220
# 0.07 emb_20
# 0.07 emb_50
# 0.07 emb_338
# 0.07 emb_163
# 0.07 emb_314
# 0.07 emb_152
# 0.07 emb_313
# 0.06 emb_40
# 0.06 emb_340
# 0.06 emb_58
# 0.06 emb_154
# 0.06 emb_101
# 0.06 emb_260
# 0.06 emb_195
# 0.06 emb_57
# 0.06 emb_176
# 0.06 emb_319
# 0.06 emb_131
# 0.06 emb_91
# 0.05 emb_87
# 0.05 emb_24
# 0.05 emb_36
# 0.05 emb_291
# 0.05 emb_216
# 0.05 emb_64
# 0.05 emb_215
# 0.05 emb_76
# 0.04 emb_116
# 0.04 emb_328
# 0.04 emb_302
# 0.04 emb_363
# 0.04 emb_169
# 0.04 emb_42
# 0.03 emb_172
# 0.03 emb_209
# 0.03 emb_48
# 0.03 emb_199
# 0.03 emb_51
# 0.02 emb_339
# 0.02 emb_282
# 0.02 emb_120
# 0.02 emb_287
# 0.02 emb_311
# 0.02 emb_165
# 0.01 emb_158
# 0.01 emb_60
# 0.01 emb_307
# 0.0 emb_300
# 0.0 emb_9
# 0.0 emb_96
# 0.0 emb_264
# 0.0 emb_310
# 0.0 emb_341

# %% [markdown]
# ### Sort original DF by the most important feature

# %%
important_df = final_df[['text', 'cat', 'emb_105']]
important_df.head(3)
# Out:
#                                   text  cat   emb_105
# 0  центра пётр наталья чем могу помочь  1.0 -0.016394
# 1                          до свидания  1.0 -0.251240
# 2       ожидайте звонок в течение часа  1.0 -0.022775

# %%
len(important_df)
# Out:
# 391003

# %%
# Remove duplicates
important_df = important_df.drop_duplicates()
len(important_df)
# Out:
# 268074

# %%
# Sort the DataFrame
sorted_df = important_df.sort_values(by='emb_105', ascending=True)

# %%
for idx, row in sorted_df[:500].iterrows():
    print(row['cat'], row.emb_105, row.text)
# Out:
# 1.0 -0.734595835 джанан
# 1.0 -0.73031199 хан
# 1.0 -0.726594269 банан
# 1.0 -0.726593971 банан
# 1.0 -0.721832454 аж
# 1.0 -0.718275011 ферран
# 1.0 -0.718231976 кран
# 1.0 -0.693701863 кан
# 1.0 -0.660895944 в клане
# 1.0 -0.650688469 брант
# 0.0 -0.65068841 брант
# 1.0 -0.641317904 планшет
# 1.0 -0.640630782 фр
# 1.0 -0.625479281 манжет
# 1.0 -0.622695923 келлер
# 1.0 -0.612567544 план
# 1.0 -0.608062208 канеш
# 1.0 -0.597115993 жан ван
# 1.0 -0.593762934 лиран
# 1.0 -0.59192276 атлант
# 0.0 -0.59192276 атлант
# 1.0 -0.591922462 атлант
# 0.0 -0.591922462 атлант
# 1.0 -0.591922402 атлант
# 1.0 -0.589240015 банка
# 1.0 -0.585074425 планерная
# 1.0 -0.585074186 планерная
# 1.0 -0.584420383 ван
# 1.0 -0.584419966 ван
# 1.0 -0.583566368 а брант
# 1.0 -0.582050383 коран
# 1.0 -0.579773605 барант
# 1.0 -0.57703954 пан
# 1.0 -0.574379206 ветеран
# 1.0 -0.569002926 дан
# 1.0 -0.569002807 дан
# 1.0 -0.569002628 дан
# 1.0 -0.566635132 алан
# 1.0 -0.566634953 алан
# 1.0 -0.566634834 алан
# 1.0 -0.566634655 алан
# 1.0 -0.566287637 ваня
# 0.0 -0.562460959 кит
# 1.0 -0.562460482 кит
# 1.0 -0.562389493 манжетка
# 1.0 -0.562125564 квитанция
# 0.0 -0.562125504 квитанция
# 1.0 -0.561982512 баня
# 1.0 -0.561982274 баня
# 1.0 -0.560932219 квартирант
# 1.0 -0.560932159 квартирант
# 1.0 -0.558507264 лиман
# 1.0 -0.558507025 лиман
# 1.0 -0.555209696 план планшет
# 1.0 -0.54727149 в атлант
# 1.0 -0.54602176 пани
# 1.0 -0.543182969 панели
# 1.0 -0.542419493 питание
# 1.0 -0.542418838 питание
# 1.0 -0.538704634 карантина
# 1.0 -0.533311009 квитанции
# 1.0 -0.533211887 ферган
# 1.0 -0.530566692 плит
# 1.0 -0.529560506 кандия
# 1.0 -0.529560328 кандия
# 1.0 -0.529560268 кандия
# 1.0 -0.529560089 кандия
# 1.0 -0.52956003 кандия
# 1.0 -0.527727783 клеймит
# 1.0 -0.525823712 от питания
# 1.0 -0.523333251 вариант
# 1.0 -0.517831445 кредит
# 1.0 -0.517521143 операция
# 1.0 -0.517050564 етаж
# 1.0 -0.515193403 полиция этаж
# 1.0 -0.512922466 ближе
# 1.0 -0.512922227 ближе
# 1.0 -0.511378288 клиент
# 1.0 -0.509604514 панель
# 1.0 -0.509604454 панель
# 1.0 -0.509604335 панель
# 1.0 -0.509604275 панель
# 1.0 -0.508615911 банкет
# 1.0 -0.508427739 хуан
# 1.0 -0.507023335 манфред
# 1.0 -0.502013624 бранд
# 1.0 -0.502013445 бранд
# 1.0 -0.502013266 бранд
# 1.0 -0.501912057 братан
# 1.0 -0.50185287 таня
# 0.0 -0.50185287 таня
# 0.0 -0.50126338 либерман
# 1.0 -0.49957636 пораньше
# 1.0 -0.499575943 пораньше
# 1.0 -0.498864353 а ближе
# 1.0 -0.498464376 элджи
# 1.0 -0.498464316 элджи
# 1.0 -0.498464257 элджи
# 1.0 -0.498463959 элджи
# 1.0 -0.495443672 флана
# 1.0 -0.495030791 фильтр
# 1.0 -0.495030701 фильтр
# 1.0 -0.495030671 фильтр
# 1.0 -0.495030612 фильтр
# 1.0 -0.493787318 тиран
# 1.0 -0.493509442 дандер
# 0.0 -0.493111581 станция
# 1.0 -0.491922677 санация
# 0.0 -0.489837915 титан
# 1.0 -0.48546043 пишет
# 1.0 -0.483993024 звание
# 1.0 -0.482152462 квартире
# 1.0 -0.482152373 квартире
# 1.0 -0.482152164 квартире
# 1.0 -0.481198609 ожидайте
# 1.0 -0.481198549 ожидайте
# 1.0 -0.48119849 ожидайте
# 1.0 -0.48119846 ожидайте
# 1.0 -0.48119837 ожидайте
# 1.0 -0.480802268 в квартире
# 1.0 -0.480802029 в квартире
# 1.0 -0.48080194 в квартире
# 1.0 -0.479155898 фи
# 1.0 -0.478209436 нет определителей нет
# 1.0 -0.477653027 картер
# 1.0 -0.477652848 картер
# 1.0 -0.475972027 полиция
# 1.0 -0.475762188 а квитанция
# 1.0 -0.475395054 китти
# 1.0 -0.474101782 канал
# 0.0 -0.473137796 калер
# 1.0 -0.471053094 сбер планете
# 1.0 -0.471043289 фанатик
# 1.0 -0.469477355 беслан
# 1.0 -0.469260544 питер
# 1.0 -0.46887365 кант кандис
# 1.0 -0.468489259 болван
# 1.0 -0.468188345 ар
# 1.0 -0.466556221 карт
# 1.0 -0.465624303 а в квитанция
# 1.0 -0.465247959 лжив
# 1.0 -0.464615583 кварт
# 1.0 -0.464615405 кварт
# 1.0 -0.464615285 кварт
# 1.0 -0.464130849 в квитанцию
# 1.0 -0.463443428 занят
# 1.0 -0.462653577 анар
# 1.0 -0.462631106 ел
# 1.0 -0.462345988 квитанцию
# 1.0 -0.46219179 одержит он
# 1.0 -0.461503029 м е л а
# 1.0 -0.461176157 иран
# 1.0 -0.461078644 липецка
# 1.0 -0.461054802 париж
# 1.0 -0.460874975 ф улице
# 1.0 -0.459024966 крафт
# 0.0 -0.458592415 квитанции и платёж
# 1.0 -0.458584726 видите
# 1.0 -0.458584517 видите
# 1.0 -0.458584398 видите
# 1.0 -0.458255768 фаер
# 1.0 -0.458255678 фаер
# 1.0 -0.457515061 здание
# 1.0 -0.457514822 здание
# 1.0 -0.457514703 здание
# 1.0 -0.457489431 метро ближайшая станция
# 1.0 -0.457489341 метро ближайшая станция
# 0.0 -0.457410723 экран
# 1.0 -0.457410723 экран
# 1.0 -0.456654936 олдман
# 1.0 -0.456112295 нет не видел
# 1.0 -0.456112236 нет не видел
# 1.0 -0.456053972 вань
# 1.0 -0.455712318 талант
# 1.0 -0.45571211 талант
# 0.0 -0.454413265 джеффри
# 1.0 -0.45440945 вартан
# 1.0 -0.454361707 видит
# 1.0 -0.4541969 лифте
# 1.0 -0.453842044 катерина
# 1.0 -0.453324169 квартирка
# 1.0 -0.45332402 квартирка
# 1.0 -0.453323931 квартирка
# 0.0 -0.453323931 квартирка
# 1.0 -0.453237385 кратер
# 1.0 -0.452957869 от лица
# 1.0 -0.452893078 не верите
# 1.0 -0.452843845 книжка
# 1.0 -0.452843666 книжка
# 1.0 -0.452843636 книжка
# 1.0 -0.452843428 книжка
# 1.0 -0.452645183 ер
# 1.0 -0.452341229 адриан
# 1.0 -0.452316433 ля
# 1.0 -0.45220226 вибрация
# 1.0 -0.451552242 е
# 1.0 -0.44977501 липецкая
# 1.0 -0.44969517 в танцев
# 0.0 -0.449532807 итан
# 1.0 -0.449531436 атлантис не атлант
# 1.0 -0.449430645 пил
# 1.0 -0.448589563 не ожидайте
# 1.0 -0.448067248 в банке
# 1.0 -0.447977871 кварте
# 1.0 -0.446342409 не видите
# 1.0 -0.446342379 не видите
# 1.0 -0.446342319 не видите
# 1.0 -0.446342289 не видите
# 1.0 -0.445393413 санти
# 1.0 -0.444707215 а атлант
# 1.0 -0.443868041 ой арман
# 0.0 -0.443680942 в этой бане
# 1.0 -0.442657173 от тринадцати
# 1.0 -0.442349553 арестант
# 0.0 -0.442266345 ор
# 1.0 -0.442251086 ожидает
# 0.0 -0.442060947 клапан
# 1.0 -0.441573739 а кипре
# 1.0 -0.441133499 арка
# 1.0 -0.44059357 нет не видим нет определителя
# 1.0 -0.440422535 кирилл
# 1.0 -0.440107644 оператор валерия
# 1.0 -0.439592123 в кулере
# 1.0 -0.439178556 меж
# 1.0 -0.438702434 мирт
# 1.0 -0.438526005 карл
# 1.0 -0.438525826 карл
# 1.0 -0.438436508 нет каштан
# 1.0 -0.437917322 метро какая-то станция ближайшая
# 1.0 -0.43718788 примечание
# 1.0 -0.436583877 крепление
# 1.0 -0.435675681 нет определителя
# 0.0 -0.435675442 нет определителя
# 1.0 -0.435609847 лайтер
# 1.0 -0.435608834 киган
# 1.0 -0.435163826 описание
# 1.0 -0.43512091 эрика
# 1.0 -0.434410661 плантацию
# 1.0 -0.434351981 экране
# 1.0 -0.433875978 хаер хаер
# 1.0 -0.433662176 банк
# 1.0 -0.43339932 эй джефф
# 1.0 -0.433324486 ниже
# 1.0 -0.43212986 нет стационара нет
# 1.0 -0.432068884 каптёрка
# 1.0 -0.431759655 андрей атлант
# 1.0 -0.431574374 не верит
# 1.0 -0.431330293 мил
# 1.0 -0.431227744 в квартир
# 1.0 -0.430588335 от свидания
# 1.0 -0.430049688 каретная
# 1.0 -0.429815859 какой ближайший метро кант
# 1.0 -0.429336101 квартир
# 1.0 -0.429336041 квартир
# 1.0 -0.429336011 квартир
# 1.0 -0.429335982 квартир
# 1.0 -0.429335952 квартир
# 1.0 -0.42904371 а верфи
# 1.0 -0.428943157 ханс аир
# 1.0 -0.428511083 иван
# 1.0 -0.428510964 иван
# 1.0 -0.428503841 фюрер
# 1.0 -0.427069962 бери скрежет
# 0.0 -0.426977694 бит
# 1.0 -0.426464707 метро ближайший это какой клан
# 1.0 -0.426391423 при отжиме
# 1.0 -0.426391333 при отжиме
# 1.0 -0.426367104 каттер
# 1.0 -0.426333874 фильмец
# 1.0 -0.425682366 лет
# 0.0 -0.425682157 лет
# 1.0 -0.425682157 лет
# 0.0 -0.425682008 лет
# 1.0 -0.42547071 обман
# 1.0 -0.425470591 обман
# 1.0 -0.425470501 обман
# 1.0 -0.425296187 какой метро станция
# 1.0 -0.4245781 фантаст
# 1.0 -0.424041897 все ожидайте
# 1.0 -0.424041867 все ожидайте
# 0.0 -0.42377001 километр
# 1.0 -0.423665732 лица лет на
# 1.0 -0.423609227 туран
# 1.0 -0.423407644 лорка
# 1.0 -0.423087209 по квитанции
# 1.0 -0.422414511 лекция
# 1.0 -0.422408968 корт
# 1.0 -0.422408909 корт
# 1.0 -0.422408789 корт
# 1.0 -0.422281116 не видит
# 1.0 -0.422218472 мир
# 1.0 -0.422218084 мир
# 1.0 -0.422217935 мир
# 0.0 -0.422217935 мир
# 1.0 -0.422204047 кандин
# 1.0 -0.421972245 лиана
# 1.0 -0.42163834 пантера
# 1.0 -0.421252668 китель
# 1.0 -0.421117216 курит
# 1.0 -0.421063155 ханша
# 1.0 -0.42088747 те пане
# 1.0 -0.420780003 е хаир
# 1.0 -0.420779914 е хаир
# 1.0 -0.420726478 не литр
# 1.0 -0.420703948 от отпил
# 1.0 -0.420616657 курица какая
# 1.0 -0.420616537 курица какая
# 1.0 -0.420610607 не переживайте
# 1.0 -0.420610487 не переживайте
# 1.0 -0.420610249 не переживайте
# 1.0 -0.420179099 он приедет приедет
# 1.0 -0.419511437 может кандзи
# 1.0 -0.419502825 перестаньте
# 1.0 -0.419379085 панель отдельная
# 1.0 -0.419009835 определить
# 1.0 -0.419002324 приедет
# 1.0 -0.419002116 приедет
# 1.0 -0.418779731 екатерина
# 1.0 -0.418779492 екатерина
# 1.0 -0.418674916 эр эф
# 1.0 -0.418463379 определителем
# 1.0 -0.418445706 планка банк
# 1.0 -0.418268532 или пораньше
# 0.0 -0.418069601 саня саня
# 1.0 -0.418048948 фили
# 1.0 -0.417826265 кор
# 0.0 -0.417826027 кор
# 1.0 -0.417825848 кор
# 1.0 -0.417825788 кор
# 1.0 -0.417162567 операция как от домофона по квартире
# 1.0 -0.417077303 также банк
# 1.0 -0.417022109 атлант или нет
# 1.0 -0.416922361 или квитанция
# 1.0 -0.41689375 белье впереди
# 1.0 -0.416831225 от мкад
# 1.0 -0.416830808 от мкад
# 1.0 -0.416763097 метро ближайшая это какое станция
# 1.0 -0.416392118 а берет и берет
# 0.0 -0.41618678 организация
# 1.0 -0.415482134 юаней
# 1.0 -0.415220588 операции
# 1.0 -0.414915264 ивантеевка
# 1.0 -0.413351417 метро ближе ближе
# 1.0 -0.413334906 от фирма канте
# 1.0 -0.412784994 лидер
# 1.0 -0.412291318 берет
# 1.0 -0.41203025 данте
# 1.0 -0.411677092 хорошо ближайшая станция
# 1.0 -0.411224514 отмечание
# 1.0 -0.410909563 метро станция ближайшая
# 1.0 -0.410459518 и париж
# 1.0 -0.410233229 лицо химки
# 1.0 -0.410110086 выпишет квитанцию
# 1.0 -0.409034818 ну какая ближайшая станция
# 1.0 -0.408987015 на квитанция
# 1.0 -0.408235848 отдельная отдельная панель
# 1.0 -0.407758713 придёт
# 1.0 -0.407061249 танец
# 1.0 -0.407019854 в кварте
# 1.0 -0.407019466 в кварте
# 1.0 -0.407019436 в кварте
# 1.0 -0.407019377 в кварте
# 1.0 -0.40674001 пир
# 1.0 -0.406632125 капитанская
# 1.0 -0.406501293 ложь
# 1.0 -0.406501174 ложь
# 1.0 -0.406190306 нет определителем
# 1.0 -0.406181335 колец
# 1.0 -0.406163305 курица дорожная
# 1.0 -0.40590176 фрейд
# 1.0 -0.405769229 название скажите
# 1.0 -0.405769169 название скажите
# 1.0 -0.40576908 название скажите
# 1.0 -0.40569073 держи ки улице
# 1.0 -0.405618668 пётр
# 1.0 -0.405618101 пётр
# 1.0 -0.405618042 пётр
# 1.0 -0.405163676 один метро какая станция
# 1.0 -0.405150771 колец какая
# 1.0 -0.40511173 бианки
# 1.0 -0.405021161 от лат
# 1.0 -0.403804213 каир
# 1.0 -0.403801739 а впереди какое название
# 1.0 -0.403663158 аш
# 1.0 -0.40366301 аш
# 1.0 -0.40366292 аш
# 1.0 -0.403662443 аш
# 1.0 -0.403374523 либхер
# 1.0 -0.403374434 либхер
# 1.0 -0.403374374 либхер
# 1.0 -0.403374314 либхер
# 1.0 -0.403103977 да теперь ожидайте
# 1.0 -0.40291205 да квитанция
# 1.0 -0.402606845 библия ближе
# 1.0 -0.402387023 курица
# 1.0 -0.402223021 не банк
# 1.0 -0.401827127 нет скажите
# 0.0 -0.401521504 от нашей органе
# 1.0 -0.400755554 прежний
# 1.0 -0.400458723 папа тиран
# 1.0 -0.400446117 один кран
# 1.0 -0.400353491 перестань
# 1.0 -0.400181741 миллиметр
# 1.0 -0.400153339 ближайший
# 1.0 -0.40015325 ближайший
# 1.0 -0.40015316 ближайший
# 1.0 -0.400153071 ближайший
# 1.0 -0.399939477 купить
# 1.0 -0.399836034 фантазия
# 1.0 -0.399694622 капитановка
# 1.0 -0.399620175 ласково метро какой ближайшая станция
# 1.0 -0.399310946 а л
# 1.0 -0.399297476 при станции
# 1.0 -0.399178684 не можете определить
# 1.0 -0.398145407 воспитание
# 0.0 -0.398145229 воспитание
# 1.0 -0.397921175 хаер
# 1.0 -0.397921085 хаер
# 1.0 -0.397920936 хаер
# 1.0 -0.397597343 компания эльбор
# 0.0 -0.397053987 он приедет
# 1.0 -0.396961093 феврале
# 1.0 -0.396858215 вторая пораньше
# 1.0 -0.396514177 кур
# 1.0 -0.39648807 заранее
# 0.0 -0.396487892 заранее
# 1.0 -0.396225035 метро какой к вам ближайшая станция
# 1.0 -0.396220773 лат
# 1.0 -0.396220744 лат
# 1.0 -0.396220714 лат
# 1.0 -0.396220684 лат
# 0.0 -0.396220624 лат
# 1.0 -0.395771384 лецитин
# 1.0 -0.395675212 курица зелёная
# 1.0 -0.395365208 петро какое ближайшее
# 1.0 -0.395113677 этаж
# 1.0 -0.395113468 этаж
# 0.0 -0.395113438 этаж
# 1.0 -0.395113438 этаж
# 1.0 -0.395113379 этаж
# 1.0 -0.395113349 этаж
# 0.0 -0.395113349 этаж
# 1.0 -0.395113319 этаж
# 1.0 -0.39511323 этаж
# 1.0 -0.394755304 ожидайте флажок
# 1.0 -0.394567519 карте
# 1.0 -0.394558012 овец этаж
# 1.0 -0.394383788 крутицкий
# 1.0 -0.393535584 привет
# 0.0 -0.393535584 привет
# 1.0 -0.393417001 а е
# 1.0 -0.39307493 квартет какая
# 1.0 -0.392719626 квант так
# 1.0 -0.392620355 второе метро ближайшая станция
# 1.0 -0.392440796 откажет
# 1.0 -0.392437607 манжета
# 1.0 -0.392189145 не набирает
# 1.0 -0.392189026 не набирает
# 1.0 -0.392188907 не набирает
# 1.0 -0.392188877 не набирает
# 1.0 -0.39217937 бергман
# 0.0 -0.392051935 платите
# 1.0 -0.391965687 как вариант
# 1.0 -0.391937196 катарина
# 1.0 -0.391902387 эта организация
# 1.0 -0.39159286 все все седане
# 1.0 -0.391376168 плита не панели
# 1.0 -0.391308039 метро какой поближе будет станция
# 1.0 -0.391267538 элджи элджи
# 1.0 -0.391201794 координат
# 1.0 -0.391121328 номер квитанции знаете
# 1.0 -0.390958965 ближайшая станция метро
# 1.0 -0.390958786 ближайшая станция метро
# 1.0 -0.390958726 ближайшая станция метро
# 1.0 -0.390958607 ближайшая станция метро
# 1.0 -0.390958518 ближайшая станция метро
# 1.0 -0.390958428 ближайшая станция метро
# 1.0 -0.390922457 кран перекройте есть
# 1.0 -0.39072004 барабан
# 1.0 -0.390578508 станция метро какая ближайшая
# 1.0 -0.390578449 станция метро какая ближайшая
# 1.0 -0.390578419 станция метро какая ближайшая
# 1.0 -0.3905783 станция метро какая ближайшая
# 1.0 -0.390490711 сани идёт
# 1.0 -0.390406162 за квартирант
# 1.0 -0.390295833 этика
# 1.0 -0.390021324 квартира скажете
# 1.0 -0.390007854 ли
# 1.0 -0.390007794 ли
# 1.0 -0.389974654 ок отель атлант
# 1.0 -0.389838099 кертин
# 1.0 -0.389837891 кертин
# 1.0 -0.389766753 ожидать
# 1.0 -0.389766723 ожидать
# 1.0 -0.389766693 ожидать
# 1.0 -0.389766634 ожидать
# 1.0 -0.389766574 ожидать
# 1.0 -0.389174014 есть квитанция
# 1.0 -0.388957649 видите какая улица
# 1.0 -0.387948036 кантемировка улица

# %%
for idx, row in sorted_df[-500:].iterrows():
    print(row['cat'], row.emb_105, row.text)
# Out:
# 1.0 0.360162169 я думаю что нет
# 0.0 0.360170752 ну мы
# 1.0 0.360357225 до ремонта что
# 1.0 0.360465735 гости да
# 1.0 0.360755473 ну да где работа
# 1.0 0.361055344 икону
# 1.0 0.361508578 снег
# 1.0 0.361684591 газовая да
# 1.0 0.361923039 давно дом
# 1.0 0.361973405 на песню
# 1.0 0.362042546 вы галочкой
# 1.0 0.362440616 на русском да
# 1.0 0.36248672 ну что ж понятно
# 0.0 0.362572193 где
# 1.0 0.362572193 где
# 1.0 0.362572223 где
# 0.0 0.362572283 где
# 1.0 0.362572402 где
# 0.0 0.362572402 где
# 1.0 0.362572432 где
# 1.0 0.3625727 где
# 1.0 0.362597764 ты чудо я могу
# 1.0 0.36284554 ты чудо
# 1.0 0.36284712 ну что да
# 1.0 0.362917125 поэтому точнее
# 1.0 0.363129228 до ясенева
# 1.0 0.363221377 гостя
# 1.0 0.363276452 по-домашнему
# 1.0 0.363340765 да память девичья
# 1.0 0.363551766 потом я
# 1.0 0.363562852 по звонку да
# 1.0 0.363610536 госет
# 1.0 0.363696814 голос
# 1.0 0.364066184 дом два
# 1.0 0.364066362 дом два
# 1.0 0.364066541 дом два
# 1.0 0.364462465 да ну там
# 1.0 0.36452648 геннадий георгиевич да
# 1.0 0.364578873 гаснет пламя да
# 1.0 0.364579082 гаснет пламя да
# 1.0 0.364579141 гаснет пламя да
# 1.0 0.365517437 ну и глупа
# 1.0 0.365655065 у нас да
# 1.0 0.36572206 гоевского
# 1.0 0.36572209 гоевского
# 1.0 0.365788847 да за грудь
# 1.0 0.366081864 тысяч
# 1.0 0.366154492 г о
# 1.0 0.366360158 ну равно
# 1.0 0.366600603 усиевича дом два да
# 0.0 0.36708301 я же там
# 1.0 0.367112786 на замену
# 1.0 0.367534041 мы я поняла
# 1.0 0.367649794 за час до
# 1.0 0.367822289 я поняла ну да
# 1.0 0.367863834 растен дом
# 1.0 0.36799562 да ты
# 1.0 0.367995828 да ты
# 1.0 0.367995888 да ты
# 1.0 0.368017465 смеха
# 1.0 0.368136853 семь тысяч да
# 1.0 0.368186653 группу
# 1.0 0.368279874 до того ж
# 0.0 0.368317425 я могу вас
# 1.0 0.368317544 я могу вас
# 1.0 0.368776947 на глаза
# 1.0 0.369078636 тощего
# 1.0 0.369209528 а я могу
# 0.0 0.369263977 всего-то
# 1.0 0.369467944 в дом
# 1.0 0.369468063 в дом
# 1.0 0.369468302 в дом
# 1.0 0.369468451 в дом
# 1.0 0.36946848 в дом
# 1.0 0.370238632 да я плену
# 1.0 0.370349824 ну где именно
# 1.0 0.370443225 но мы
# 1.0 0.37075755 да конечно могу
# 1.0 0.371138155 да ну их
# 1.0 0.371640146 чудно
# 1.0 0.37170586 ну там вы
# 1.0 0.371878624 да дон
# 1.0 0.371895403 наш голос
# 1.0 0.371908158 да где именно
# 1.0 0.371908307 да где именно
# 1.0 0.372069389 у нас нету
# 1.0 0.372069657 у нас нету
# 1.0 0.372074485 но где именно
# 1.0 0.372074604 но где именно
# 1.0 0.372273564 газ
# 1.0 0.372716904 весенняя дом угу
# 0.0 0.373037398 угодно
# 1.0 0.373256952 а почему
# 0.0 0.37325713 а почему
# 1.0 0.373421162 то то
# 1.0 0.373876423 но увы мы
# 1.0 0.374138981 а не по-моему
# 1.0 0.374184787 за работу за работу за ремонт да
# 1.0 0.374647349 да я дома
# 1.0 0.374774069 сегодня я
# 1.0 0.374836326 гренаду
# 1.0 0.374947757 а ясно
# 1.0 0.375372887 инга
# 1.0 0.375452906 да я отмечу
# 1.0 0.375548691 там где в женского
# 1.0 0.375655591 ну у
# 1.0 0.376045376 ну то
# 1.0 0.376045555 ну то
# 1.0 0.376045942 ну то
# 1.0 0.376425207 ты нас
# 1.0 0.376834095 я не расслышал
# 1.0 0.377305716 самсунг да
# 1.0 0.377305895 самсунг да
# 1.0 0.377306074 самсунг да
# 1.0 0.377443314 не расслышала ремонт чего
# 1.0 0.377462476 и много
# 1.0 0.377595216 говору
# 0.0 0.377629578 до года музыки
# 1.0 0.378047496 ну понятно ясно
# 1.0 0.378085554 я громко
# 1.0 0.378091037 носом
# 1.0 0.378244847 запах газа
# 1.0 0.378924489 ну ты
# 1.0 0.379832745 тягу
# 1.0 0.38013944 да у кого-то
# 0.0 0.380407333 что там где-то
# 1.0 0.380716801 ну да что там
# 0.0 0.381078422 да у нас много
# 1.0 0.381445825 готово
# 1.0 0.381445885 готово
# 1.0 0.381445974 готово
# 1.0 0.381446034 готово
# 1.0 0.381506383 гузель
# 1.0 0.381893486 рынок
# 0.0 0.382345229 ясно все
# 1.0 0.382370502 о уточню
# 1.0 0.383387774 ремонт до чего
# 1.0 0.383387804 ремонт до чего
# 1.0 0.383527279 чего
# 1.0 0.383527517 чего
# 1.0 0.383527607 чего
# 0.0 0.383527607 чего
# 1.0 0.383527875 чего
# 0.0 0.383527875 чего
# 1.0 0.383590966 ростов на дону
# 0.0 0.383591056 ростов на дону
# 1.0 0.383896738 тогда мы
# 1.0 0.384029925 я не шучу
# 1.0 0.384145945 но над рекламу
# 1.0 0.384181887 рама
# 1.0 0.384403527 моем да
# 0.0 0.384509683 ну дагу
# 1.0 0.384533733 домах
# 1.0 0.385654628 у нас рима
# 0.0 0.385987282 дачу
# 1.0 0.386092484 так гримау дом
# 1.0 0.386293858 то
# 1.0 0.386294067 то
# 1.0 0.386294186 то
# 0.0 0.386294246 то
# 1.0 0.386294246 то
# 1.0 0.386294425 то
# 1.0 0.386294633 то
# 1.0 0.386771739 по району
# 1.0 0.386989802 ну я по нему
# 1.0 0.387099594 гален
# 1.0 0.387343675 я вас понял мэм
# 1.0 0.388502419 по ремонту че
# 0.0 0.388527751 град
# 0.0 0.388711542 у нас у мыса на мыс
# 1.0 0.389083385 да помог
# 1.0 0.389165401 я поняла их
# 1.0 0.389305472 ген о да
# 1.0 0.389940381 ну почему не могу
# 1.0 0.390385449 там граунд
# 1.0 0.391061842 у самого
# 1.0 0.391140312 у чего
# 1.0 0.39114061 у чего
# 1.0 0.392043769 но у него на руках
# 1.0 0.392367512 не греет угу
# 1.0 0.392417789 ума
# 1.0 0.392417848 ума
# 1.0 0.392718166 много
# 1.0 0.393382549 уч
# 1.0 0.393666804 да дыбом
# 1.0 0.39377448 потому что да
# 1.0 0.393846095 по ремонту чем
# 1.0 0.393855095 этого года да
# 1.0 0.393855125 этого года да
# 1.0 0.393855155 этого года да
# 1.0 0.393878549 выгнута
# 1.0 0.39390263 ну той то рядом
# 1.0 0.393950522 до духа
# 1.0 0.394136012 смутно
# 1.0 0.395031244 у него на руках
# 1.0 0.395237148 да да дом
# 1.0 0.395237207 да да дом
# 1.0 0.395359933 да дома
# 1.0 0.395681381 я я могу
# 1.0 0.395858556 ремонта чего
# 1.0 0.396383464 не ну я дома
# 1.0 0.396444142 в голову
# 1.0 0.39645648 дом дом
# 1.0 0.396456599 дом дом
# 1.0 0.396456629 дом дом
# 1.0 0.39647451 гаминда
# 1.0 0.396542996 ты там
# 0.0 0.396543324 ты там
# 1.0 0.396701187 рено
# 1.0 0.39809826 у нас
# 0.0 0.39809826 у нас
# 1.0 0.39809832 у нас
# 1.0 0.398098469 у нас
# 0.0 0.398098737 у нас
# 1.0 0.398098737 у нас
# 1.0 0.398193091 гбб два дом
# 0.0 0.398202479 мы у нас
# 1.0 0.398217589 ясенево
# 1.0 0.399257004 где не расслышала
# 1.0 0.399382502 да готово
# 1.0 0.400659412 ну что ж денусь
# 1.0 0.401126772 могу
# 0.0 0.401126772 могу
# 1.0 0.401126862 могу
# 1.0 0.40112707 могу
# 1.0 0.4011271 могу
# 1.0 0.401127189 могу
# 0.0 0.401127577 могу
# 1.0 0.401127577 могу
# 1.0 0.40132913 да ясно ясно
# 1.0 0.401560366 углу да
# 1.0 0.401644677 но где
# 1.0 0.402351975 да на почте по моему где то я не помню точно
# 0.0 0.402503878 ремонт чего
# 1.0 0.402503878 ремонт чего
# 1.0 0.403443128 всюду
# 0.0 0.404009908 почему вы
# 1.0 0.404089719 точно
# 0.0 0.404089779 точно
# 1.0 0.404089779 точно
# 1.0 0.404089868 точно
# 0.0 0.404089957 точно
# 1.0 0.404089957 точно
# 1.0 0.4041906 все я понял голым
# 1.0 0.404776782 звоню
# 1.0 0.404785007 вы где
# 1.0 0.404868364 уму
# 1.0 0.404868424 уму
# 1.0 0.406372935 по глазах
# 1.0 0.406613499 газда
# 1.0 0.406837285 глаза
# 1.0 0.406837434 глаза
# 1.0 0.406950474 дно
# 0.0 0.406961203 что где
# 1.0 0.407409817 тесно
# 1.0 0.407515764 у кого-то
# 1.0 0.407720298 но там
# 1.0 0.408768982 много да
# 1.0 0.40876928 много да
# 1.0 0.409656197 помню
# 1.0 0.410069615 до дамы
# 1.0 0.410265535 до георга
# 1.0 0.410407066 деньгах
# 1.0 0.410477549 за глаза
# 1.0 0.410645276 инзу
# 0.0 0.41145277 йому
# 1.0 0.41145286 йому
# 1.0 0.41165933 думаю
# 1.0 0.41165939 думаю
# 1.0 0.411785334 самсунг
# 1.0 0.411785424 самсунг
# 1.0 0.411785454 самсунг
# 0.0 0.411785454 самсунг
# 1.0 0.411785483 самсунг
# 1.0 0.411785603 самсунг
# 1.0 0.412876904 в гагры
# 1.0 0.413304657 голубую
# 1.0 0.413924426 а ногу
# 1.0 0.41402775 согласно умным
# 1.0 0.414206713 да потому что
# 1.0 0.414817929 горыня
# 1.0 0.414861172 по-разному
# 1.0 0.415254384 да много
# 1.0 0.415254533 да много
# 1.0 0.415254653 да много
# 0.0 0.415455222 чего там
# 1.0 0.416238368 гнусная
# 1.0 0.416884094 ну где где-то
# 1.0 0.416992605 чем могу
# 1.0 0.417118818 ты сам
# 1.0 0.417176366 гостях
# 1.0 0.417609036 не могу
# 1.0 0.417609125 не могу
# 1.0 0.417609185 не могу
# 1.0 0.417609304 не могу
# 1.0 0.417877883 на том
# 1.0 0.417878062 на том
# 1.0 0.419093072 темно
# 1.0 0.419747412 всему
# 1.0 0.420251757 умы
# 1.0 0.420626849 я жду конечно
# 1.0 0.421785355 демон
# 1.0 0.421980143 галстуку
# 1.0 0.422012657 гения
# 1.0 0.422954261 домом
# 1.0 0.42295441 домом
# 1.0 0.423754424 гас узнал
# 1.0 0.425238431 том
# 1.0 0.425238609 том
# 0.0 0.425238699 том
# 1.0 0.425238699 том
# 1.0 0.425239086 том
# 0.0 0.425279915 но почему
# 0.0 0.425280094 но почему
# 1.0 0.425810456 много их
# 1.0 0.425909549 поэтому
# 0.0 0.425909668 поэтому
# 1.0 0.425909728 поэтому
# 0.0 0.425909936 поэтому
# 1.0 0.425909936 поэтому
# 1.0 0.426179975 ну ясно
# 1.0 0.427611232 почему
# 1.0 0.427611321 почему
# 1.0 0.427611351 почему
# 0.0 0.427611351 почему
# 1.0 0.427611768 почему
# 0.0 0.427611768 почему
# 1.0 0.428645164 по ремонту чего
# 1.0 0.428645253 по ремонту чего
# 1.0 0.428645343 по ремонту чего
# 0.0 0.428645343 по ремонту чего
# 1.0 0.428750128 да я поняла поэтому я
# 1.0 0.429339349 гастелло
# 1.0 0.429641366 точно да
# 1.0 0.429719388 том два
# 0.0 0.429725736 да да по нему
# 0.0 0.429812461 почему на дом
# 1.0 0.430510163 граунд
# 0.0 0.430885077 готэм прошу
# 1.0 0.431586653 да на дому
# 1.0 0.43168354 на дом
# 1.0 0.43168363 на дом
# 1.0 0.431683749 на дом
# 1.0 0.431683838 на дом
# 1.0 0.431683958 на дом
# 1.0 0.432346344 зонтом
# 1.0 0.432724983 я не могу
# 1.0 0.433555812 по галочку
# 1.0 0.433605343 да по-моему то рядом где-то
# 1.0 0.433629125 дым
# 1.0 0.433671325 да могу
# 1.0 0.433671415 да могу
# 1.0 0.433671445 да могу
# 1.0 0.433678299 содом
# 1.0 0.435632855 гальса
# 1.0 0.437501043 угно
# 1.0 0.438014984 да ясно
# 1.0 0.438352823 чего-то
# 1.0 0.438405156 умно
# 0.0 0.439485967 голова
# 0.0 0.439486176 голова
# 1.0 0.439784527 что дом
# 1.0 0.440915704 газовые
# 1.0 0.440943569 глава
# 1.0 0.440943956 глава
# 1.0 0.440943986 глава
# 1.0 0.440944105 глава
# 1.0 0.440944195 глава
# 1.0 0.440944284 глава
# 1.0 0.441967636 дом
# 0.0 0.441967636 дом
# 0.0 0.441967875 дом
# 1.0 0.441967875 дом
# 1.0 0.441967905 дом
# 0.0 0.441967905 дом
# 1.0 0.441968113 дом
# 1.0 0.441968143 дом
# 1.0 0.441968262 дом
# 1.0 0.441968292 дом
# 1.0 0.444259048 я поняла русь
# 1.0 0.444675356 угу
# 1.0 0.444675446 угу
# 1.0 0.444675505 угу
# 0.0 0.444675505 угу
# 1.0 0.444675535 угу
# 1.0 0.444675744 угу
# 0.0 0.444675773 угу
# 1.0 0.444675773 угу
# 1.0 0.444675833 угу
# 1.0 0.445365906 год год
# 1.0 0.445554256 глупо
# 1.0 0.446568519 сейчас я глотну
# 1.0 0.447463632 томсон
# 1.0 0.447463661 томсон
# 1.0 0.448787063 ногу
# 1.0 0.450432092 усиевича я поняла
# 1.0 0.450726599 усиевича
# 1.0 0.451206297 за дом
# 1.0 0.451206475 за дом
# 1.0 0.451206595 за дом
# 1.0 0.454567641 я могу
# 1.0 0.45456785 я могу
# 1.0 0.454568297 я могу
# 0.0 0.454568297 я могу
# 1.0 0.454568326 я могу
# 1.0 0.454568386 я могу
# 1.0 0.456509829 ух ты
# 1.0 0.458816677 дома
# 1.0 0.458817095 дома
# 1.0 0.458817124 дома
# 1.0 0.458817244 дома
# 1.0 0.458817333 дома
# 1.0 0.458817393 дома
# 1.0 0.459955305 по ремонту
# 1.0 0.459955394 по ремонту
# 0.0 0.459955394 по ремонту
# 0.0 0.459955424 по ремонту
# 1.0 0.459955424 по ремонту
# 1.0 0.460246354 я нему
# 1.0 0.461988032 да дом
# 1.0 0.461988181 да дом
# 1.0 0.46198824 да дом
# 1.0 0.4619883 да дом
# 1.0 0.461988389 да дом
# 1.0 0.463766307 чугун
# 0.0 0.464135647 гада
# 1.0 0.464450598 гаграх
# 1.0 0.465093106 дом да
# 1.0 0.468146056 густая
# 1.0 0.470710069 гору
# 1.0 0.471629381 гагенау
# 1.0 0.473427266 ну том
# 1.0 0.473910451 раму
# 1.0 0.474406421 сын
# 1.0 0.474445969 всю
# 1.0 0.476072252 госта
# 0.0 0.476477534 гастон
# 1.0 0.476725578 усиевича дом
# 1.0 0.479281366 грау де
# 0.0 0.480116427 да год
# 1.0 0.482883841 ген
# 1.0 0.482884258 ген
# 1.0 0.484961122 готовы
# 1.0 0.485256255 умысла
# 1.0 0.487671137 год да
# 1.0 0.488758087 два года я понесу
# 1.0 0.489461839 да том
# 1.0 0.490055263 ясно ясно
# 1.0 0.490055472 ясно ясно
# 1.0 0.490072638 года
# 1.0 0.490073234 года
# 1.0 0.49203378 уточню
# 1.0 0.492033809 уточню
# 1.0 0.492034018 уточню
# 0.0 0.492034137 уточню
# 1.0 0.492240936 я по-моему
# 1.0 0.492490679 год
# 1.0 0.492490858 год
# 1.0 0.493991166 но год да
# 0.0 0.500093222 на дому
# 1.0 0.500093341 на дому
# 1.0 0.503078222 ясно
# 1.0 0.503078341 ясно
# 0.0 0.503078401 ясно
# 1.0 0.503078401 ясно
# 1.0 0.50307852 ясно
# 1.0 0.503078759 ясно
# 0.0 0.503078878 ясно
# 1.0 0.503078878 ясно
# 1.0 0.506600857 газеты
# 1.0 0.50835526 ты где
# 1.0 0.509042144 горным
# 1.0 0.510891259 галку
# 1.0 0.51115346 за год до
# 1.0 0.515489817 ну дом
# 1.0 0.519838929 губам
# 1.0 0.521975696 галю
# 1.0 0.525388241 жу где
# 1.0 0.525465429 гинзу
# 1.0 0.525465906 гинзу
# 0.0 0.530467391 да поэтому
# 1.0 0.533818066 губы
# 1.0 0.539584517 том ну
# 1.0 0.544441104 до года
# 1.0 0.549119651 я помню
# 1.0 0.549201012 да да в том году
# 1.0 0.552875996 ну год
# 1.0 0.552876174 ну год
# 1.0 0.553103685 гонюсь
# 1.0 0.557798862 го
# 1.0 0.55779922 го
# 0.0 0.565595508 гам
# 1.0 0.56710887 я понемногу
# 1.0 0.569658697 яною
# 1.0 0.577384353 в том году
# 1.0 0.578800976 но го
# 1.0 0.607288182 гума
# 1.0 0.638764262 гунча
# 1.0 0.648874164 году
# 1.0 0.726204395 гоу
